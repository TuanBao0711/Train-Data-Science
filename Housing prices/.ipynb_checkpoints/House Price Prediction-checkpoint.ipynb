# %% [markdown]
# # House Price Prediction
# ## 1. Problem Definition:
# - Predict the sale price for each house in project

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#Read csv file by pandas
df = pd.read_csv('train.csv')
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %%
#Set 'Id' column to Index
df = pd.read_csv('train.csv', index_col= 'Id')
df.head(10)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 7           20       RL         75.0    10084   Pave   NaN      Reg
# 8           60       RL          NaN    10382   Pave   NaN      IR1
# 9           50       RM         51.0     6120   Pave   NaN      Reg
# 10         190       RL         50.0     7420   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 6          Lvl    AllPub    Inside  ...        0    NaN  MnPrv        Shed
# 7          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 8          Lvl    AllPub    Corner  ...        0    NaN    NaN        Shed
# 9          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 10         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
# 6      700     10    2009        WD         Normal     143000
# 7        0      8    2007        WD         Normal     307000
# 8      350     11    2009        WD         Normal     200000
# 9        0      4    2008        WD        Abnorml     129900
# 10       0      1    2008        WD         Normal     118000
#
# [10 rows x 80 columns]

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
ft = ['LotArea','YearBuilt','1stFlrSF', '2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']

# %%
x_data = df[ft]
y_data = df['SalePrice']
x_data.head()
# y_data.head()
# Out:
#     LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# Id
# 1      8450       2003       856       854         2             3
# 2      9600       1976      1262         0         2             3
# 3     11250       2001       920       866         2             3
# 4      9550       1915       961       756         1             3
# 5     14260       2000      1145      1053         2             4
#
#     TotRmsAbvGrd
# Id
# 1              8
# 2              6
# 3              6
# 4              7
# 5              9

# %%
from sklearn.model_selection import train_test_split
# np.random.seed(1)
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, train_size= 0.8, test_size= 0.2, random_state= 0)

# %%
x_train
# Out:
#       LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# Id
# 619     11694       2007      1828         0         2             3
# 871      6600       1962       894         0         1             2
# 93      13360       1921       964         0         1             2
# 818     13265       2002      1689         0         2             3
# 303     13704       2001      1541         0         2             3
# ...       ...        ...       ...       ...       ...           ...
# 764      9430       1999      1268      1097         2             3
# 836      9600       1950      1067         0         2             2
# 1217     8930       1978      1318       584         2             4
# 560      3196       2003      1557         0         2             2
# 685     16770       1998      1195       644         2             4
#
#       TotRmsAbvGrd
# Id
# 619              9
# 871              5
# 93               5
# 818              7
# 303              6
# ...            ...
# 764              8
# 836              4
# 1217             8
# 560              7
# 685              7
#
# [1168 rows x 7 columns]

# %%
#Using Tree Decision
from sklearn.tree import DecisionTreeRegressor
dt_model = DecisionTreeRegressor(random_state=1)

# %%
dt_model.fit(x_train , y_train)
y_prd = dt_model.predict(x_test)
# y_prd

# %%
#Compare y with y_prd
pd.DataFrame({'y': y_test.head(10), 'y_predict':y_prd[:10]})
# Out:
#            y  y_predict
# Id
# 530   200624   335000.0
# 492   133000   140200.0
# 460   110000   119000.0
# 280   192000   207500.0
# 656    88000   112000.0
# 1014   85000    58500.0
# 1404  282922   232600.0
# 602   141000   119500.0
# 1183  745000   755000.0
# 688   148800   156932.0

# %%
#Using Forest Regressor 
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
RFR = RandomForestRegressor(random_state=1)

# %%
RFR.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=1)

# %%
RFR_prd = RFR.predict(x_test)

# %%
#Compare Y_test with RFR_prd
pd.DataFrame({"Y_Test":y_test.head(10),"RFR_prd":RFR_prd[:10]})
# Out:
#       Y_Test        RFR_prd
# Id
# 530   200624  271690.000000
# 492   133000  155039.000000
# 460   110000  122024.000000
# 280   192000  188915.000000
# 656    88000   91147.000000
# 1014   85000   88533.200000
# 1404  282922  240518.240000
# 602   141000  126286.000000
# 1183  745000  624269.120000
# 688   148800  174312.253333

# %%
# print('Tree DecisionTree             ')
# print(pd.DataFrame({'Y_test': y_test.head(20), }))
print('TreeDecision and RandomForest')
print(pd.DataFrame({"Y_Test":y_test.head(20),'Tree_predict':y_prd[:20] , "RandomForest_prd":RFR_prd[:20]}))
# Out:
# TreeDecision and RandomForest
#       Y_Test  Tree_predict  RandomForest_prd
# Id
# 530   200624      335000.0     271690.000000
# 492   133000      140200.0     155039.000000
# 460   110000      119000.0     122024.000000
# 280   192000      207500.0     188915.000000
# 656    88000      112000.0      91147.000000
# 1014   85000       58500.0      88533.200000
# 1404  282922      232600.0     240518.240000
# 602   141000      119500.0     126286.000000
# 1183  745000      755000.0     624269.120000
# 688   148800      156932.0     174312.253333
# 1318  208900      213500.0     209138.460000
# 1004  136905      100000.0     147714.500000
# 1301  225000      244000.0     233088.250000
# 1393  123000      130000.0     123139.500000
# 1015  119200      144900.0     140503.750000
# 255   145000      123000.0     139187.000000
# 1323  190000      236000.0     232538.300000
# 90    123600      126000.0     134260.000000
# 32    149350      154500.0     145952.240000
# 483   155000      128000.0     130562.050000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_compare = pd.DataFrame({"Y_Test":y_test.head(20),'Tree_predict':y_prd[:20] , "RandomForest_prd":RFR_prd[:20]})
df_compare.sort_values('Id')
plt.plot(df_compare['Y_Test']);

# %%
from sklearn.metrics import mean_squared_error

# %%
print("Mean squared error Tree Decision:",mean_squared_error(y_test, y_prd))
print("Mean squared error Random Forest Regressor:",mean_squared_error(y_test, RFR_prd))
# Out:
# Mean squared error Tree Decision: 3228225028.8561645
# Mean squared error Random Forest Regressor: 1489870679.523267

# %% [markdown]
# Mean squared error Tree Decision is bigger than Mean squared error Random Forest Regressor

# %%
house_df = pd.read_csv('test.csv', index_col= 'Id')
house_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1461         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 1462         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 1463         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1464         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1465         HLS    AllPub    Inside  ...         144        0    NaN    NaN
# ...          ...       ...       ...  ...         ...      ...    ...    ...
# 2915         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2916         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2917         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2918         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 2919         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1461         NaN       0       6    2010        WD         Normal
# 1462        Gar2   12500       6    2010        WD         Normal
# 1463         NaN       0       3    2010        WD         Normal
# 1464         NaN       0       6    2010        WD         Normal
# 1465         NaN       0       1    2010        WD         Normal
# ...          ...     ...     ...     ...       ...            ...
# 2915         NaN       0       6    2006        WD         Normal
# 2916         NaN       0       4    2006        WD        Abnorml
# 2917         NaN       0       9    2006        WD        Abnorml
# 2918        Shed     700       7    2006        WD         Normal
# 2919         NaN       0      11    2006        WD         Normal
#
# [1459 rows x 79 columns]

# %%
house_data = house_df[ft]
house_data
# Out:
#       LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# Id
# 1461    11622       1961       896         0         1             2
# 1462    14267       1958      1329         0         1             3
# 1463    13830       1997       928       701         2             3
# 1464     9978       1998       926       678         2             3
# 1465     5005       1992      1280         0         2             2
# ...       ...        ...       ...       ...       ...           ...
# 2915     1936       1970       546       546         1             3
# 2916     1894       1970       546       546         1             3
# 2917    20000       1960      1224         0         1             4
# 2918    10441       1992       970         0         1             3
# 2919     9627       1993       996      1004         2             3
#
#       TotRmsAbvGrd
# Id
# 1461             5
# 1462             6
# 1463             6
# 1464             7
# 1465             5
# ...            ...
# 2915             5
# 2916             6
# 2917             7
# 2918             6
# 2919             9
#
# [1459 rows x 7 columns]

# %%
House_price_predict = RFR.predict
